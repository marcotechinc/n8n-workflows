# %%
# Supabase client
from supabase import create_client

# Numerical processing
import json
import numpy as np

SUPABASE_URL = "https://rfcmhcxcfnlbfgmlcabi.supabase.co"
SUPABASE_ANON_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InJmY21oY3hjZm5sYmZnbWxjYWJpIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTA2MzIzOTMsImV4cCI6MjA2NjIwODM5M30.yi0SMovFIIfQRnzlj1dswkLKfebg2YmFhBbgzIuqVxI"

# Create Supabase client
supabase = create_client(SUPABASE_URL, SUPABASE_ANON_KEY)

# ----------------------------
# Paginated fetch
# ----------------------------
rows = []
page_size = 1000
offset = 0

while True:
    res = (
        supabase
        .table("status_watch_incidents")  # change table if needed
        .select("id, score, cluster_id") # TODO: Need to add score column
        .range(offset, offset + page_size - 1)
        .execute()
    )

    batch = res.data
    if not batch:
        break

    rows.extend(batch)
    offset += page_size

print(f"Fetched {len(rows)} rows")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[2], line 27
#      19 offset = 0
#      21 while True:
#      22     res = (
#      23         supabase
#      24         .table("status_watch_incidents")  # change table if needed
#      25         .select("id, score, cluster_id")
#      26         .range(offset, offset + page_size - 1)
# ---> 27         .execute()
#      28     )
#      30     batch = res.data
#      31     if not batch:
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python313\Lib\site-packages\postgrest\_sync\request_builder.py:53, in SyncQueryRequestBuilder.execute(self)
#      51     else:
#      52         json_obj = model_validate_json(APIErrorFromJSON, r.content)
# ---> 53         raise APIError(dict(json_obj))
#      54 except ValidationError as e:
#      55     raise APIError(generate_default_error_message(r))
#
# APIError: {'message': 'column status_watch_incidents.score does not exist', 'code': '42703', 'hint': None, 'details': None}

# %%
# ----------------------------
# Parse embeddings
# ----------------------------
# Supabase Data API returns embeddings as JSON strings,
# so we must parse them before using NumPy
X = np.vstack([
    json.loads(r["embedding"])   # convert string -> list[float]
    for r in rows
]).astype(float)                 # ensure numeric dtype

# Final sanity check
print(X.shape)   # (n_rows, 1536)
# Out:
# (100, 1536)

# %%
# TODO: OR Part
